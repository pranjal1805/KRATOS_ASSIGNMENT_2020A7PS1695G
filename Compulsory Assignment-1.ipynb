# %%
import numpy as np
from PIL import Image as im

# %%
from skimage import io
photo = io.imread('project.jpg')
type(photo)
# Out:
# numpy.ndarray

# %%
photo.shape
# Out:
# (1000, 1000, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(photo)

# %%
photo = 255- photo
plt.imshow(photo)

# %%
 data = im.fromarray(photo)

# %%
data.save('new_save.jpg')
